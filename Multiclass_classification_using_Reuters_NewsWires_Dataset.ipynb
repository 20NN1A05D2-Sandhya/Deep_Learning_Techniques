# %% [markdown]
# <a href="https://colab.research.google.com/github/20NN1A05D2-Sandhya/Deep_Learning_Techniques/blob/main/Multiclass_classification_using_Reuters_NewsWires_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 1s 0us/step

# %%
#Each review (row) is of different size. This data needs to be made uniform.
# i.e. each reviuew (i.e. row) needs to be onehotencoded to a length of 10,000 (we have decided to have only 10000 features)
import numpy as np
from keras.utils import to_categorical

def OneHotEncoding_fn(ReutersData, dimension=10000):
    # 8982 x 10k matrix of zeros
    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):
        #Selectively make indices as 1 based on availability of word in the review.
        OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data

x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
#create the layers
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]


model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 2s 69ms/step - loss: 2.6779 - categorical_accuracy: 0.4831 - val_loss: 1.8115 - val_categorical_accuracy: 0.6438
# Epoch 2/25
# 16/16 [==============================] - 1s 49ms/step - loss: 1.5436 - categorical_accuracy: 0.6847 - val_loss: 1.3448 - val_categorical_accuracy: 0.6925
# Epoch 3/25
# 16/16 [==============================] - 1s 53ms/step - loss: 1.1847 - categorical_accuracy: 0.7422 - val_loss: 1.1698 - val_categorical_accuracy: 0.7375
# Epoch 4/25
# 16/16 [==============================] - 1s 52ms/step - loss: 0.9690 - categorical_accuracy: 0.7879 - val_loss: 1.0513 - val_categorical_accuracy: 0.7788
# Epoch 5/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.8066 - categorical_accuracy: 0.8244 - val_loss: 0.9956 - val_categorical_accuracy: 0.8012
# Epoch 6/25
# 16/16 [==============================] - 1s 50ms/step - loss: 0.6746 - categorical_accuracy: 0.8576 - val_loss: 0.9609 - val_categorical_accuracy: 0.7837
# Epoch 7/25
# 16/16 [==============================] - 1s 46ms/step - loss: 0.5676 - categorical_accuracy: 0.8785 - val_loss: 0.9338 - val_categorical_accuracy: 0.7900
# Epoch 8/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.4785 - categorical_accuracy: 0.8992 - val_loss: 0.9014 - val_categorical_accuracy: 0.8012
# Epoch 9/25
# 16/16 [==============================] - 1s 70ms/step - loss: 0.4058 - categorical_accuracy: 0.9163 - val_loss: 0.8718 - val_categorical_accuracy: 0.8175
# Epoch 10/25
# 16/16 [==============================] - 1s 82ms/step - loss: 0.3486 - categorical_accuracy: 0.9268 - val_loss: 0.8751 - val_categorical_accuracy: 0.8175
# Epoch 11/25
# 16/16 [==============================] - 1s 79ms/step - loss: 0.3012 - categorical_accuracy: 0.9358 - val_loss: 0.9095 - val_categorical_accuracy: 0.7975
# Epoch 12/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.2648 - categorical_accuracy: 0.9408 - val_loss: 0.8744 - val_categorical_accuracy: 0.8200
# Epoch 13/25
# 16/16 [==============================] - 1s 50ms/step - loss: 0.2325 - categorical_accuracy: 0.9473 - val_loss: 0.8715 - val_categorical_accuracy: 0.8263
# Epoch 14/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.2105 - categorical_accuracy: 0.9485 - val_loss: 0.8753 - val_categorical_accuracy: 0.8213
# Epoch 15/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1889 - categorical_accuracy: 0.9518 - val_loss: 0.9223 - val_categorical_accuracy: 0.8112
# Epoch 16/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1726 - categorical_accuracy: 0.9545 - val_loss: 0.9243 - val_categorical_accuracy: 0.8100
# Epoch 17/25
# 16/16 [==============================] - 1s 52ms/step - loss: 0.1652 - categorical_accuracy: 0.9547 - val_loss: 0.9200 - val_categorical_accuracy: 0.8112
# Epoch 18/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1482 - categorical_accuracy: 0.9560 - val_loss: 0.9382 - val_categorical_accuracy: 0.8100
# Epoch 19/25
# 16/16 [==============================] - 1s 52ms/step - loss: 0.1401 - categorical_accuracy: 0.9567 - val_loss: 0.9590 - val_categorical_accuracy: 0.8075
# Epoch 20/25
# 16/16 [==============================] - 1s 51ms/step - loss: 0.1354 - categorical_accuracy: 0.9560 - val_loss: 0.9714 - val_categorical_accuracy: 0.8062
# Epoch 21/25
# 16/16 [==============================] - 1s 51ms/step - loss: 0.1304 - categorical_accuracy: 0.9570 - val_loss: 0.9676 - val_categorical_accuracy: 0.8100
# Epoch 22/25
# 16/16 [==============================] - 1s 50ms/step - loss: 0.1233 - categorical_accuracy: 0.9569 - val_loss: 1.0131 - val_categorical_accuracy: 0.8037
# Epoch 23/25
# 16/16 [==============================] - 1s 50ms/step - loss: 0.1184 - categorical_accuracy: 0.9573 - val_loss: 1.0039 - val_categorical_accuracy: 0.8025
# Epoch 24/25
# 16/16 [==============================] - 1s 80ms/step - loss: 0.1177 - categorical_accuracy: 0.9578 - val_loss: 0.9987 - val_categorical_accuracy: 0.8062
# Epoch 25/25
# 16/16 [==============================] - 1s 83ms/step - loss: 0.1141 - categorical_accuracy: 0.9565 - val_loss: 0.9968 - val_categorical_accuracy: 0.8112

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
